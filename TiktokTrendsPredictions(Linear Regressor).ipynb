# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', None)

# %%
tiktok_trends = pd.read_csv('tiktok.csv', na_values=['-'])

# %%
tiktok_trends.shape # '(Rows, Columns)'
# Out:
# (6746, 23)

# %%
tiktok_trends.head(10)
# Out:
#                  track_id                                  track_name  \
# 0  6kVuF2PYLuvl9T85XjNbaO                     Lay It Down Gmix - Main
# 1  1RGIjMFMgJxkZHMDXVYzOJ                      Bartender (feat. Akon)
# 2  1RGIjMFMgJxkZHMDXVYzOJ                      Bartender (feat. Akon)
# 3  1dIWPXMX4kRHj6Dt2DStUQ                Chosen (feat. Ty Dolla $ign)
# 4  4QVS8YCpK71R4FsxSMCjhP               Tie Me Down (with Elley Duhé)
# 5  7BoobGhD4x5K96Me0hqC8Q                               Build a Bitch
# 6  7BoobGhD4x5K96Me0hqC8Q                               Build a Bitch
# 7  5OKHUpNLi4GEQ0aynz9VLJ                                  Ever After
# 8  3J8EOeKLTLXORtWPpOU5bE                            Calling My Phone
# 9  5caZgotE4D6elZpd5S4wlX  Clap For 'Em (feat. Flo Milli & Sada Baby)
#
#                 artist_id    artist_name                album_id  duration  \
# 0  1Xfmvd48oOhEWkscWyEbh9          Lloyd  43C6GVlhXG4KfZuEbxty3r    302186
# ...

# %%
tiktok_trends['popularity'].corr(tiktok_trends['danceability'])
# Out:
# -0.09416337122681101

# %%
tiktok_trends['popularity'].corr(tiktok_trends['energy'])
# Out:
# -0.033400554745592864

# %%
tiktok_trends['popularity'].corr(tiktok_trends['key'])
# Out:
# 0.03383722276343226

# %%
tiktok_trends['popularity'].corr(tiktok_trends['loudness'])
# Out:
# 0.12026617251043

# %%
tiktok_trends['popularity'].corr(tiktok_trends['speechiness'])
# Out:
# -0.026279126319493855

# %%
tiktok_trends['popularity'].corr(tiktok_trends['acousticness'])
# Out:
# 0.0452939129839574

# %%
tiktok_trends['popularity'].corr(tiktok_trends['instrumentalness'])
# Out:
# -0.10598814453033152

# %%
tiktok_trends['popularity'].corr(tiktok_trends['liveness'])
# Out:
# -0.002109682631633075

# %%
tiktok_trends['popularity'].corr(tiktok_trends['valence'])
# Out:
# -0.07463709527940762

# %%
tiktok_trends['popularity'].corr(tiktok_trends['tempo'])
# Out:
# -0.04117814570319149

# %%
tiktok_trends['popularity'].corr(tiktok_trends['duration_mins'])
# Out:
# 0.007601153376190966

# %%
tiktok_trends['popularity'].corr(tiktok_trends['duration'])
# Out:
# 0.007601153376190902

# %%
tiktok_trends=tiktok_trends.drop_duplicates(subset=['track_id', 'popularity'], keep=False) # 'Drop duplicated rows and columns'

# %%
tiktok_trends.shape # '(Rows, Columns)'
# Out:
# (2630, 23)

# %%
tiktok_trends.head(10)
# Out:
#                   track_id                         track_name  \
# 4   4QVS8YCpK71R4FsxSMCjhP      Tie Me Down (with Elley Duhé)
# 7   5OKHUpNLi4GEQ0aynz9VLJ                         Ever After
# 23  0CAfXk7DXMnon4gLudAp7J                 Low (feat. T-Pain)
# 30  27UcQ6dAvQrgH9C880rCM3    Love You Different (feat. BEAM)
# 35  6HU7h9RYOaPRFeh0R3UeAr                            deja vu
# 38  3jagJCUbdqhDSPuxP8cAqF                            Work It
# 39  5B0kei3VVWCH7752PfDQsQ                      Rich Boy Trap
# 41  7MC4XR9M9amdmKQr2iDF7i                Iko Iko (My Bestie)
# 65  5hjn1xQQvOXD85j83j7lRr                                Aya
# 79  0ZquDRUoxvC4QXHlBfRePZ  Alo Michael - rico rico rico rico
#
#                  artist_id           artist_name                album_id  \
# 4   2ZRQcIgzPCVaT9XKhXZIzh               Gryffin  69t8rpgBN1ov5kCU6LDMuR
# 7   1mCY2mHctggfYiEqpCgcSz         Bonnie Bailey  4TrCexUUlnxL5cNen7qMt9
# ...

# %%
tiktok_trends.to_csv('tiktok_trends_removed_duplicates.csv')

# %%
tiktok_trends['popularity'].corr(tiktok_trends['duration'])
# Out:
# 0.008203735847153903

# %%
tiktok_trends['popularity'].corr(tiktok_trends['duration_mins'])
# Out:
# 0.008203735847153852

# %%
tiktok_trends['popularity'].corr(tiktok_trends['danceability'])
# Out:
# -0.13999699660578313

# %%
tiktok_trends['popularity'].corr(tiktok_trends['energy'])
# Out:
# -0.027229767078857933

# %%
tiktok_trends['popularity'].corr(tiktok_trends['key'])
# Out:
# -0.002202578442814714

# %%
tiktok_trends['popularity'].corr(tiktok_trends['loudness'])
# Out:
# 0.11099995239035593

# %%
tiktok_trends['popularity'].corr(tiktok_trends['speechiness'])
# Out:
# -0.015816374134388432

# %%
tiktok_trends['popularity'].corr(tiktok_trends['acousticness'])
# Out:
# 0.06515897974783455

# %%
tiktok_trends['popularity'].corr(tiktok_trends['instrumentalness'])
# Out:
# -0.09073824924374478

# %%
tiktok_trends['popularity'].corr(tiktok_trends['liveness'])
# Out:
# -0.021057661633515277

# %%
tiktok_trends['popularity'].corr(tiktok_trends['valence'])
# Out:
# -0.10968037454924444

# %%
tiktok_trends['popularity'].corr(tiktok_trends['tempo'])
# Out:
# -0.03193438177024995

# %%
tiktok_trends.columns
# Out:
# Index(['track_id', 'track_name', 'artist_id', 'artist_name', 'album_id',
#        'duration', 'release_date', 'popularity', 'danceability', 'energy',
#        'key', 'loudness', 'mode', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo', 'playlist_id',
#        'playlist_name', 'duration_mins', 'genre'],
#       dtype='object')

# %%
tiktok_trends = tiktok_trends [['track_id', 'track_name', 'artist_id', 'artist_name', 'album_id',
       'duration', 'popularity', 'danceability', 'energy',
       'key', 'loudness', 'speechiness', 'acousticness',
       'instrumentalness', 'liveness', 'valence', 'tempo', 'duration_mins', 'genre']]

# %%
tiktok_trends.head(10)
# Out:
#                   track_id                         track_name  \
# 4   4QVS8YCpK71R4FsxSMCjhP      Tie Me Down (with Elley Duhé)
# 7   5OKHUpNLi4GEQ0aynz9VLJ                         Ever After
# 23  0CAfXk7DXMnon4gLudAp7J                 Low (feat. T-Pain)
# 30  27UcQ6dAvQrgH9C880rCM3    Love You Different (feat. BEAM)
# 35  6HU7h9RYOaPRFeh0R3UeAr                            deja vu
# 38  3jagJCUbdqhDSPuxP8cAqF                            Work It
# 39  5B0kei3VVWCH7752PfDQsQ                      Rich Boy Trap
# 41  7MC4XR9M9amdmKQr2iDF7i                Iko Iko (My Bestie)
# 65  5hjn1xQQvOXD85j83j7lRr                                Aya
# 79  0ZquDRUoxvC4QXHlBfRePZ  Alo Michael - rico rico rico rico
#
#                  artist_id           artist_name                album_id  \
# 4   2ZRQcIgzPCVaT9XKhXZIzh               Gryffin  69t8rpgBN1ov5kCU6LDMuR
# 7   1mCY2mHctggfYiEqpCgcSz         Bonnie Bailey  4TrCexUUlnxL5cNen7qMt9
# ...

# %%
tiktok_trends['genre'].nunique()
# Out:
# 4

# %%
unique_values = tiktok_trends['genre'].unique()

# %%
print(unique_values)
# Out:
# ['TIKTOK DANCE' 'TIKTOK OPM' 'TIKTOK PHILIPPINES' '_TIKTOK']

# %%
tiktok_trends = tiktok_trends [['track_id', 'track_name','artist_id', 'artist_name', 'album_id',
       'duration', 'popularity', 'danceability', 'energy',
       'key', 'loudness', 'speechiness', 'acousticness',
       'instrumentalness', 'liveness', 'valence', 'tempo', 'duration_mins']]

# %%
tiktok_trends.head(10)
# Out:
#                   track_id                         track_name  \
# 4   4QVS8YCpK71R4FsxSMCjhP      Tie Me Down (with Elley Duhé)
# 7   5OKHUpNLi4GEQ0aynz9VLJ                         Ever After
# 23  0CAfXk7DXMnon4gLudAp7J                 Low (feat. T-Pain)
# 30  27UcQ6dAvQrgH9C880rCM3    Love You Different (feat. BEAM)
# 35  6HU7h9RYOaPRFeh0R3UeAr                            deja vu
# 38  3jagJCUbdqhDSPuxP8cAqF                            Work It
# 39  5B0kei3VVWCH7752PfDQsQ                      Rich Boy Trap
# 41  7MC4XR9M9amdmKQr2iDF7i                Iko Iko (My Bestie)
# 65  5hjn1xQQvOXD85j83j7lRr                                Aya
# 79  0ZquDRUoxvC4QXHlBfRePZ  Alo Michael - rico rico rico rico
#
#                  artist_id           artist_name                album_id  \
# 4   2ZRQcIgzPCVaT9XKhXZIzh               Gryffin  69t8rpgBN1ov5kCU6LDMuR
# 7   1mCY2mHctggfYiEqpCgcSz         Bonnie Bailey  4TrCexUUlnxL5cNen7qMt9
# ...

# %%
tiktok_trends.to_csv("tiktok_trends_removed_columns_not_needed.csv")

# %%
tiktok_trends.isna().sum()
# Out:
# track_id            0
# track_name          0
# artist_id           0
# artist_name         0
# album_id            0
# duration            0
# popularity          0
# danceability        0
# energy              0
# key                 0
# loudness            0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# duration_mins       0
# dtype: int64

# %%
tiktok_trends.hist(bins=60, figsize=(20,15))
# Out:
# array([[<Axes: title={'center': 'duration'}>,
#         <Axes: title={'center': 'popularity'}>,
#         <Axes: title={'center': 'danceability'}>,
#         <Axes: title={'center': 'energy'}>],
#        [<Axes: title={'center': 'key'}>,
#         <Axes: title={'center': 'loudness'}>,
#         <Axes: title={'center': 'speechiness'}>,
#         <Axes: title={'center': 'acousticness'}>],
#        [<Axes: title={'center': 'instrumentalness'}>,
#         <Axes: title={'center': 'liveness'}>,
#         <Axes: title={'center': 'valence'}>,
#         <Axes: title={'center': 'tempo'}>],
#        [<Axes: title={'center': 'duration_mins'}>, <Axes: >, <Axes: >,
#         <Axes: >]], dtype=object)

# %%
justin_bieber_trends = tiktok_trends[tiktok_trends['artist_name']=='Justin Bieber']

# %%
justin_bieber_trends
# Out:
#                     track_id                       track_name  \
# 30    27UcQ6dAvQrgH9C880rCM3  Love You Different (feat. BEAM)
# 729   5Isz0twJeFdduOQEFQLezv                        Confident
# 2301  0yIywEquxORnu1dR0WYsdN                          Love Me
# 2494  7HWetAoWK9qkFM575HONAY       Lonely (with benny blanco)
# 2529  6epn3r7S14KUqlReYr77hA                             Baby
# 4024  2o9LAypwGH4ctV0i9boo6d                   Come Around Me
# 5715  70XP39KE8vTgxtRXcwfxJA                 All That Matters
# 5988  27UcQ6dAvQrgH9C880rCM3  Love You Different (feat. BEAM)
#
#                    artist_id    artist_name                album_id  duration  \
# 30    1uNFoZAHBGtllmzznpCI3s  Justin Bieber  5dGWwsZ9iB2Xc3UKR0gif2    186695
# 729   1uNFoZAHBGtllmzznpCI3s  Justin Bieber  7Cz0XcQzoxUi7L7sfgXLml    248133
# 2301  1uNFoZAHBGtllmzznpCI3s  Justin Bieber  1rG5TDs3jYh6OU753I54CI    191573
# 2494  1uNFoZAHBGtllmzznpCI3s  Justin Bieber  3ILTeVimMva0ImF0dWtoQC    149297
# ...

# %%
justin_bieber_trends.to_csv('justin_bieber_trends.csv')

# %%
olivia_rodrigo_trends = tiktok_trends[tiktok_trends['artist_name']=='Olivia Rodrigo']

# %%
olivia_rodrigo_trends
# Out:
#                     track_id  \
# 35    6HU7h9RYOaPRFeh0R3UeAr
# 1264  6PERP62TejQjgHu81OHxgM
# 1449  4Yxc55NX3tAXC2mHRAhtcW
# 5039  4ZtFanR9U6ndgddUvNcjcG
# 5639  5JCoSi02qi3jJeHdZXMmR8
# 5646  1v6svH1Fyx9C1nIt1mA2DT
# 5648  2TOzTqQXNmR2zDJXihjZ2e
# 5989  6HU7h9RYOaPRFeh0R3UeAr
#
#                                              track_name  \
# 35                                              deja vu
# 1264                                           good 4 u
# 1449  All I Want - From "High School Musical: The Mu...
# 5039                                           good 4 u
# 5639                                     favorite crime
# 5646                                         All I Want
# 5648                                     enough for you
# 5989                                            deja vu
#
#                    artist_id     artist_name                album_id  \
# 35    1McMsnEElThX1knmY4oliG  Olivia Rodrigo  6s84u2TUpR3wdUv4NgKA2j
# ...

# %%
olivia_rodrigo_trends.to_csv('olivia_rodrigo_trends.csv')

# %%
Dua_Lipa_trends = tiktok_trends[tiktok_trends['artist_name']=='Dua Lipa']

# %%
Dua_Lipa_trends
# Out:
#                     track_id             track_name               artist_id  \
# 1546  7kJlTKjNZVT26iwiDUVhRm  Blow Your Mind (Mwah)  6M2wZ9GZgrQXHCFfjv46we
# 2330  1nYeVF5vIBxMxfPoL0SIWg            Hallucinate  6M2wZ9GZgrQXHCFfjv46we
# 4162  4lS8vbVu0gT5QH9LiCZdnA        Don't Start Now  6M2wZ9GZgrQXHCFfjv46we
#
#      artist_name                album_id  duration  popularity  danceability  \
# 1546    Dua Lipa  7fb7W4noziWjuzWsdr3DzT    178583          71         0.654
# 2330    Dua Lipa  7fJJK56U9fHixgO0HQkhtI    208505          74         0.627
# 4162    Dua Lipa  7eG6JYHuQicVV0dnCuPH2L    183290           0         0.793
#
#       energy  key  loudness  speechiness  acousticness  instrumentalness  \
# 1546   0.796    2    -4.761        0.122        0.0188               0.0
# 2330   0.690   10    -5.396        0.139        0.0330               0.0
# 4162   0.793   11    -4.521        0.083        0.0123               0.0
#
#       liveness  valence    tempo  duration_mins
# ...

# %%
Dua_Lipa_trends.to_csv('Dua_Lipa_trends.csv')

# %%
Artists = tiktok_trends[['artist_id', 'artist_name']]

# %%
Artists.value_counts
# Out:
# <bound method DataFrame.value_counts of                    artist_id     artist_name
# 4     2ZRQcIgzPCVaT9XKhXZIzh         Gryffin
# 7     1mCY2mHctggfYiEqpCgcSz   Bonnie Bailey
# 23    0jnsk9HBra6NMjO2oANoPY        Flo Rida
# 30    1uNFoZAHBGtllmzznpCI3s   Justin Bieber
# 35    1McMsnEElThX1knmY4oliG  Olivia Rodrigo
# ...                      ...             ...
# 6737  3e7awlrlDSwF3iM0WBjGMp      Little Mix
# 6741  0Vw76uk7P8yVtTClWyOhac           HONNE
# 6742  7bXgB6jMjp9ATFy66eO08Z     Chris Brown
# 6743  6jJ0s89eD6GaHleKKya26X      Katy Perry
# 6745  41MozSoPIsD1dJM0CLPjZF       BLACKPINK
#
# [2630 rows x 2 columns]>

# %%
Katy_Perry_trends = tiktok_trends[tiktok_trends['artist_name']=='Katy Perry']

# %%
Katy_Perry_trends
# Out:
#                     track_id             track_name               artist_id  \
# 1558  2xLOMHjkOK8nzxJ4r6yOKR               Birthday  6jJ0s89eD6GaHleKKya26X
# 2553  14iN3o8ptQ8cFVZTEmyQRV        I Kissed A Girl  6jJ0s89eD6GaHleKKya26X
# 2562  3OtMnyUaiipcAT23A8liyi            Swish Swish  6jJ0s89eD6GaHleKKya26X
# 3583  4jbmgIyjGoXjY01XxatOx6             Dark Horse  6jJ0s89eD6GaHleKKya26X
# 3593  4uQY80TKE1u4ZQZQKHzVEi  The One That Got Away  6jJ0s89eD6GaHleKKya26X
# 4161  5jrdCoLpJSvHHorevXBATy             Dark Horse  6jJ0s89eD6GaHleKKya26X
# 6710  4jbmgIyjGoXjY01XxatOx6             Dark Horse  6jJ0s89eD6GaHleKKya26X
# 6716  4uQY80TKE1u4ZQZQKHzVEi  The One That Got Away  6jJ0s89eD6GaHleKKya26X
# 6724  4uqh9bualXNHXXwO2wPorc                Daisies  6jJ0s89eD6GaHleKKya26X
# 6743  5PYQUBXc7NYeI1obMKSJK0      Never Really Over  6jJ0s89eD6GaHleKKya26X
#
#      artist_name                album_id  duration  popularity  danceability  \
# ...

# %%
Katy_Perry_trends.to_csv('Katy_Perry_trends.csv')

# %%
Black_Pink_trends = tiktok_trends[tiktok_trends['artist_id']=='41MozSoPIsD1dJM0CLPjZF']

# %%
Black_Pink_trends
# Out:
#                     track_id                     track_name  \
# 2515  3vAn0qZzdyuHamcrpkfiX3              How You Like That
# 3705  2J4P46vCFm1rPkNkp9pZWX  Ice Cream (with Selena Gomez)
# 4113  2k0e6dy1tx7fE6m126Ydfw  Ice Cream (with Selena Gomez)
# 6696  6y6k14YN6MbKpGIv1Rk00Q              How You Like That
# 6745  60jpDubMmVyR5molJp2TCm  Ice Cream (with Selena Gomez)
#
#                    artist_id artist_name                album_id  duration  \
# 2515  41MozSoPIsD1dJM0CLPjZF   BLACKPINK  19LMUlWN7xU2NW80pZSeuH    181263
# 3705  41MozSoPIsD1dJM0CLPjZF   BLACKPINK  2VBb4LRcRSACOfJWRUgVZl    175813
# 4113  41MozSoPIsD1dJM0CLPjZF   BLACKPINK  7nZPZCnwS90jrRjGNjzv4D    175813
# 6696  41MozSoPIsD1dJM0CLPjZF   BLACKPINK  1AkGUEtocePYti6xefsECx    181263
# 6745  41MozSoPIsD1dJM0CLPjZF   BLACKPINK  0J1uiXQshfRtz2R8lgUlQk    175813
#
#       popularity  danceability  energy  key  loudness  speechiness  \
# 2515          16         0.828   0.782   11    -4.014       0.0918
# ...

# %%
Black_Pink_trends.to_csv('Black_Pink_trends.csv')

# %%
tiktok_trends = tiktok_trends [['track_id', 'track_name','artist_id', 'artist_name', 'album_id', 'popularity', 'danceability', 'energy',
       'key', 'loudness', 'speechiness', 'acousticness',
       'instrumentalness', 'liveness', 'valence', 'tempo', 'duration_mins']]

# %%
tiktok_trends.head(10)
# Out:
#                   track_id                         track_name  \
# 4   4QVS8YCpK71R4FsxSMCjhP      Tie Me Down (with Elley Duhé)
# 7   5OKHUpNLi4GEQ0aynz9VLJ                         Ever After
# 23  0CAfXk7DXMnon4gLudAp7J                 Low (feat. T-Pain)
# 30  27UcQ6dAvQrgH9C880rCM3    Love You Different (feat. BEAM)
# 35  6HU7h9RYOaPRFeh0R3UeAr                            deja vu
# 38  3jagJCUbdqhDSPuxP8cAqF                            Work It
# 39  5B0kei3VVWCH7752PfDQsQ                      Rich Boy Trap
# 41  7MC4XR9M9amdmKQr2iDF7i                Iko Iko (My Bestie)
# 65  5hjn1xQQvOXD85j83j7lRr                                Aya
# 79  0ZquDRUoxvC4QXHlBfRePZ  Alo Michael - rico rico rico rico
#
#                  artist_id           artist_name                album_id  \
# 4   2ZRQcIgzPCVaT9XKhXZIzh               Gryffin  69t8rpgBN1ov5kCU6LDMuR
# 7   1mCY2mHctggfYiEqpCgcSz         Bonnie Bailey  4TrCexUUlnxL5cNen7qMt9
# ...

# %%
justin_bieber_trends.hist(bins=60, figsize=(20,15))
# Out:
# array([[<Axes: title={'center': 'duration'}>,
#         <Axes: title={'center': 'popularity'}>,
#         <Axes: title={'center': 'danceability'}>,
#         <Axes: title={'center': 'energy'}>],
#        [<Axes: title={'center': 'key'}>,
#         <Axes: title={'center': 'loudness'}>,
#         <Axes: title={'center': 'speechiness'}>,
#         <Axes: title={'center': 'acousticness'}>],
#        [<Axes: title={'center': 'instrumentalness'}>,
#         <Axes: title={'center': 'liveness'}>,
#         <Axes: title={'center': 'valence'}>,
#         <Axes: title={'center': 'tempo'}>],
#        [<Axes: title={'center': 'duration_mins'}>, <Axes: >, <Axes: >,
#         <Axes: >]], dtype=object)

# %%
olivia_rodrigo_trends.hist(bins=60, figsize=(20,15))
# Out:
# array([[<Axes: title={'center': 'duration'}>,
#         <Axes: title={'center': 'popularity'}>,
#         <Axes: title={'center': 'danceability'}>,
#         <Axes: title={'center': 'energy'}>],
#        [<Axes: title={'center': 'key'}>,
#         <Axes: title={'center': 'loudness'}>,
#         <Axes: title={'center': 'speechiness'}>,
#         <Axes: title={'center': 'acousticness'}>],
#        [<Axes: title={'center': 'instrumentalness'}>,
#         <Axes: title={'center': 'liveness'}>,
#         <Axes: title={'center': 'valence'}>,
#         <Axes: title={'center': 'tempo'}>],
#        [<Axes: title={'center': 'duration_mins'}>, <Axes: >, <Axes: >,
#         <Axes: >]], dtype=object)

# %%
Katy_Perry_trends.hist(bins=60, figsize=(20,15))
# Out:
# array([[<Axes: title={'center': 'duration'}>,
#         <Axes: title={'center': 'popularity'}>,
#         <Axes: title={'center': 'danceability'}>,
#         <Axes: title={'center': 'energy'}>],
#        [<Axes: title={'center': 'key'}>,
#         <Axes: title={'center': 'loudness'}>,
#         <Axes: title={'center': 'speechiness'}>,
#         <Axes: title={'center': 'acousticness'}>],
#        [<Axes: title={'center': 'instrumentalness'}>,
#         <Axes: title={'center': 'liveness'}>,
#         <Axes: title={'center': 'valence'}>,
#         <Axes: title={'center': 'tempo'}>],
#        [<Axes: title={'center': 'duration_mins'}>, <Axes: >, <Axes: >,
#         <Axes: >]], dtype=object)

# %%
Black_Pink_trends.hist(bins=60, figsize=(20,15))
# Out:
# array([[<Axes: title={'center': 'duration'}>,
#         <Axes: title={'center': 'popularity'}>,
#         <Axes: title={'center': 'danceability'}>,
#         <Axes: title={'center': 'energy'}>],
#        [<Axes: title={'center': 'key'}>,
#         <Axes: title={'center': 'loudness'}>,
#         <Axes: title={'center': 'speechiness'}>,
#         <Axes: title={'center': 'acousticness'}>],
#        [<Axes: title={'center': 'instrumentalness'}>,
#         <Axes: title={'center': 'liveness'}>,
#         <Axes: title={'center': 'valence'}>,
#         <Axes: title={'center': 'tempo'}>],
#        [<Axes: title={'center': 'duration_mins'}>, <Axes: >, <Axes: >,
#         <Axes: >]], dtype=object)

# %%
Dua_Lipa_trends.hist(bins=60, figsize=(20,15))
# Out:
# array([[<Axes: title={'center': 'duration'}>,
#         <Axes: title={'center': 'popularity'}>,
#         <Axes: title={'center': 'danceability'}>,
#         <Axes: title={'center': 'energy'}>],
#        [<Axes: title={'center': 'key'}>,
#         <Axes: title={'center': 'loudness'}>,
#         <Axes: title={'center': 'speechiness'}>,
#         <Axes: title={'center': 'acousticness'}>],
#        [<Axes: title={'center': 'instrumentalness'}>,
#         <Axes: title={'center': 'liveness'}>,
#         <Axes: title={'center': 'valence'}>,
#         <Axes: title={'center': 'tempo'}>],
#        [<Axes: title={'center': 'duration_mins'}>, <Axes: >, <Axes: >,
#         <Axes: >]], dtype=object)

# %%
tiktok_trends.dtypes
# Out:
# track_id             object
# track_name           object
# artist_id            object
# artist_name          object
# album_id             object
# popularity            int64
# danceability        float64
# energy              float64
# key                   int64
# loudness            float64
# speechiness         float64
# acousticness        float64
# instrumentalness    float64
# liveness            float64
# valence             float64
# tempo               float64
# duration_mins       float64
# dtype: object

# %%
pd.DataFrame(tiktok_trends.value_counts("key")).plot(kind='bar')
# Out:
# <Axes: xlabel='key'>

# %%
tiktok_trends.columns
# Out:
# Index(['track_id', 'track_name', 'artist_id', 'artist_name', 'album_id',
#        'popularity', 'danceability', 'energy', 'key', 'loudness',
#        'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'duration_mins'],
#       dtype='object')

# %%
training_data = tiktok_trends[['popularity', 'danceability', 'energy', 'key', 'loudness',
       'speechiness', 'acousticness', 'instrumentalness', 'liveness',
       'valence', 'tempo', 'duration_mins']]

# %%
training_data.dtypes
# Out:
# popularity            int64
# danceability        float64
# energy              float64
# key                   int64
# loudness            float64
# speechiness         float64
# acousticness        float64
# instrumentalness    float64
# liveness            float64
# valence             float64
# tempo               float64
# duration_mins       float64
# dtype: object

# %%
training_data.head(10)
# Out:
#     popularity  danceability  energy  key  loudness  speechiness  \
# 4           72         0.548   0.839    6    -2.371       0.0644
# 7           50         0.774   0.800   11    -6.504       0.0314
# 23          80         0.918   0.609   10    -5.640       0.0791
# 30          72         0.759   0.584    8    -6.655       0.0600
# 35          88         0.442   0.612    2    -7.222       0.1120
# 38          71         0.884   0.677    1    -5.603       0.2830
# 39          42         0.776   0.584    1   -10.606       0.0873
# 41          81         0.862   0.753    5    -5.356       0.0625
# 65          35         0.708   0.823   11    -5.261       0.0508
# 79          35         0.853   0.667    9   -10.256       0.0823
#
#     acousticness  instrumentalness  liveness  valence    tempo  duration_mins
# 4         0.1350          0.000000    0.1020    0.314   98.932       3.638250
# 7         0.2590          0.000004    0.0888    0.902  113.994       3.859317
# ...

# %%
training_data.to_csv('training_data_with_key.csv')

# %%
X_trends = tiktok_trends[['danceability', 'energy', 'loudness',
       'speechiness','acousticness', 'instrumentalness', 'liveness',
     'tempo', 'duration_mins']] # Valence was dropped due to giving better clf scores for the linear regressor when dropped
X_trends = pd.get_dummies(X_trends)
Y_trends = tiktok_trends[['popularity']]

# %%
X_trends.to_csv('training_data_without_valence.csv')

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X_trends, Y_trends, test_size=0.30, random_state=15)

# %%
X_train.value_counts()
# Out:
# danceability  energy  loudness  speechiness  acousticness  instrumentalness  liveness  tempo    duration_mins
# 0.765         0.618   -8.049    0.1030       0.298000      0.000000          0.1100    109.986  3.100000         3
# 0.871         0.364   -13.598   0.1610       0.136000      0.000000          0.1620    119.922  2.468217         3
# 0.442         0.612   -7.222    0.1120       0.584000      0.000006          0.3700    180.917  3.591767         2
# 0.707         0.570   -8.276    0.0446       0.049800      0.000000          0.1020    170.033  2.452450         2
# 0.764         0.302   -5.984    0.0340       0.546000      0.000000          0.1200    94.039   2.981433         2
#                                                                                                                 ..
# 0.674         0.592   -8.115    0.0817       0.355000      0.000000          0.3150    83.992   2.488083         1
# ...

# %%
from sklearn.linear_model import LinearRegression

clf = LinearRegression().fit(X_train, Y_train)

# %%
Y_pred = clf.predict(X_test)
Y_pred
# Out:
# array([[46.70166724],
#        [48.44616877],
#        [50.05937646],
#        [46.77450497],
#        [44.04945891],
#        [48.32331464],
#        [48.94592602],
#        [47.84858284],
#        [48.46973243],
#        [45.65117726],
#        [40.64611663],
#        [52.18685873],
#        [45.90393532],
#        [51.90462045],
#        [48.47631711],
#        [48.06096813],
#        [40.74785178],
#        [48.31266732],
#        [52.10128613],
#        [41.42637652],
#        [38.63082356],
#        [46.83456563],
#        [48.28007967],
#        [54.87059257],
#        [39.20593034],
#        [46.87254421],
#        [51.80234835],
#        [50.99619176],
#        [46.30338918],
#        [39.45743518],
#        [50.90039417],
#        [40.28419143],
#        [50.9917182 ],
#        [51.58894212],
#        [55.77212381],
#        [51.66208677],
#        [50.30821068],
#        [51.97964709],
#        [39.6652304 ],
#        [51.06034812],
#        [48.60816197],
# ...

# %%
clf.score(X_test, Y_test)
# Out:
# 0.07577700728225112
